# %%
import pandas as pd
import matplotlib.pyplot as plt
weather_data = pd.read_csv("weather.csv")

# %%
weather_data_sorted = []

for line in weather_data[:20]:
    element = line.split(',')
    weather_data_sorted.append(element)

print(weather_data_sorted)
# Out:
# [['Data_Precipitation'], ['Date_Full'], ['Date_Month'], ['Date_Week of'], ['Date_Year'], ['Station_City'], ['Station_Code'], ['Station_Location'], ['Station_State'], ['Data_Temperature_Avg Temp'], ['Data_Temperature_Max_Temp'], ['Data_Temperature_Min_Temp'], ['Data_Wind_Direction'], ['Data_Wind_Speed']]

# %%
weather_data = pd.read_csv("weather.csv")
weather_data
# Out:
#        Data_Precipitation   Date_Full  Date_Month  Date_Week of  Date_Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station_City Station_Code Station_Location Station_State  \
# 0       Birmingham          BHM   Birmingham, AL       Alabama
# 1       Huntsville          HSV   Huntsville, AL       Alabama
# 2           Mobile          MOB       Mobile, AL       Alabama
# 3       Montgomery          MGM   Montgomery, AL       Alabama
# 4        Anchorage          ANC    Anchorage, AK        Alaska
# ...            ...          ...              ...           ...
# 16738       Casper          CPR       Casper, WY       Wyoming
# 16739     Cheyenne          CYS     Cheyenne, WY       Wyoming
# 16740       Lander          LND       Lander, WY       Wyoming
# 16741      Rawlins          RWL      Rawlins, WY       Wyoming
# 16742     Sheridan          SHR     Sheridan, WY       Wyoming
#
#        Data_Temperature_Avg Temp  Data_Temperature_Max_Temp  \
# 0                             39                         46
# 1                             39                         47
# 2                             46                         51
# 3                             45                         52
# 4                             34                         38
# ...                          ...                        ...
# 16738                         23                         32
# 16739                         32                         42
# 16740                         17                         29
# 16741                         23                         31
# 16742                         21                         34
#
#        Data_Temperature_Min_Temp  Data_Wind_Direction  Data_Wind_Speed
# 0                             32                   33             4.33
# 1                             31                   32             3.86
# 2                             41                   35             9.73
# 3                             38                   32             6.86
# 4                             29                   19             7.80
# ...                          ...                  ...              ...
# 16738                         15                   23            19.98
# 16739                         21                   26            15.16
# 16740                          4                   26             1.65
# 16741                         13                   24            18.16
# 16742                          8                   23             7.51
#
# [16743 rows x 14 columns]

# %%
# Out:
# count    16743.000000
# mean         6.343128
# std          3.490723
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%          9.000000
# max         12.000000
# Name: Date_Month, dtype: float64

# %%
weather_data.Data_Wind_Speed.describe()
# Out:
# count    16743.000000
# mean         6.329820
# std          3.494785
# min          0.000000
# 25%          4.040000
# 50%          5.940000
# 75%          8.080000
# max         61.100000
# Name: Data_Wind_Speed, dtype: float64

# %%
weather_data.Data_Precipitation.describe()
# Out:
# count    16743.000000
# mean         0.579090
# std          0.988057
# min          0.000000
# 25%          0.000000
# 50%          0.190000
# 75%          0.750000
# max         20.890000
# Name: Data_Precipitation, dtype: float64

# %%
weather_data.Data_Precipitation.value_counts()
# Out:
# Data_Precipitation
# 0.00    4324
# 0.01     549
# 0.02     366
# 0.03     333
# 0.04     279
#         ...
# 4.63       1
# 4.94       1
# 5.22       1
# 4.48       1
# 3.66       1
# Name: count, Length: 565, dtype: int64

# %%
weather_data = weather_data[weather_data['Data_Precipitation'] > 0]

weather_data = weather_data[weather_data['Data_Wind_Speed'] < 40]

# %%
clean_rain_data = rain_data[
    (rain_data['Data_Wind_Speed'] < 60) &
    (weather_data['Data_Precipitation'] < 5)
]

# %%
plt.scatter(clean_weather_data['Data_Wind_Speed'], clean_weather_data['Data_Precipitation'], s=1)

plt.xlabel("Wind Speed")
plt.ylabel("Precipitation")
plt.title("Precipitation vs Wind Speed")

plt.show()

# %%
total_yearly_rain = weather_data.groupby('Date_Month')['Data_Precipitation'].sum()
total_yearly_rain.plot(kind= 'bar', figsize=(10,5), xlabel="Month Number", ylabel="Total Precipitation",title= "Total Percipitation in each Month in the United States")
# Out:
# <Axes: title={'center': 'Total Percipitation in each Month in the United States'}, xlabel='Month Number', ylabel='Total Precipitation'>

# %%
total_yearly_wind = weather_data.groupby('Date_Month')['Data_Wind_Speed'].mean()
total_yearly_wind.plot(kind= 'bar', figsize=(10,5), xlabel="Month Number", ylabel="Average Wind", title= "Average Wind Speed in each Month in the United States")
# Out:
# <Axes: title={'center': 'Average Wind Speed in each Month in the United States'}, xlabel='Month Number', ylabel='Average Wind'>

# %%
total_yearly_wind = weather_data.groupby('Date_Month')['Data_Temperature_Max_Temp'].mean()
total_yearly_wind.plot(kind= 'bar', figsize=(10,5), xlabel="Month Number", ylabel="Average Temperature High", title= "Average Temperature Highs for each Month in the United States")
# Out:
# <Axes: title={'center': 'Average Temperature Highs for each Month in the United States'}, xlabel='Month Number', ylabel='Average Temperature High'>
